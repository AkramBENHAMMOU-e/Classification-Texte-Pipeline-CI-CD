# %%
import pandas as pd

# Charger un échantillon des données prétraitées
train_df = pd.read_csv('../data/processed/train.csv')

print('Shape du DataFrame :', train_df.shape)
print('\nColonnes :', train_df.columns.tolist())

print('\nPremières lignes :')
display(train_df.head())

print('\nExemple détaillé (première ligne) :')
display(train_df.iloc[0])
# Out:
# Shape du DataFrame : (12811, 4)
#
# Colonnes : ['text', 'target', 'cleaned_text', 'processed_text']
#
# Premières lignes :
#                                                 text  target  \
# 0  \n\nBeing a chronic HBsAg carrier does not nec...      13
# 1  Hi guys,\n\tI've been hearing lots of talk on ...      14
# 2  The whire wheels aren't chromed, they were to ...       7
# 3  \nHuh?  Clemens pitched last on Saturday, givi...       9
# 4  \n\n\nOr how about:\n    "End light pollution ...      14
#
#                                         cleaned_text  \
# 0  being a chronic hbsag carrier does not necessa...
# 1  hi guys\n\tive been hearing lots of talk on th...
# 2  the whire wheels arent chromed they were to be...
# 3  huh  clemens pitched last on saturday giving h...
# 4  or how about\n    end light pollution now\n\ny...
#
#                                       processed_text
# 0  chronic hbsag carrier necessarily mean patient...
# ...
